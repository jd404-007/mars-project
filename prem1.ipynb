# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense ,Dropout ,LeakyReLU
from tensorflow.keras import regularizers
from sklearn.metrics import accuracy_score, classification_report , f1_score

np.random.seed(42)
tf.random.set_seed(42)

#1. Load the features and labels CSV
df = pd.read_csv("ravdess_features.csv")

# Stop and warn if it's empty
if df.shape[0] == 0:
    raise ValueError("The CSV file is empty. Check your preprocessing step.")

# 3. Separate features and labels
X = df.drop("label", axis=1)
y = df["label"]

# 4. Encode string labels to integers
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# 5. 80-20 train-validation split with stratification
X_train, X_val, y_train, y_val = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)


#Scaling the validation and training data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

model = Sequential([
    Dense(256 , activation='relu',kernel_regularizer=regularizers.l2(0.001)),
    Dense(128 , activation='relu',kernel_regularizer=regularizers.l2(0.001)),
    Dense(64 , activation='relu',kernel_regularizer=regularizers.l2(0.001)),
    Dense(8 , activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train_scaled,y_train,epochs=50)



# Predict probabilities for a batch of inputs
y_pred_probs = model.predict(X_val_scaled)   # shape: (num_samples, num_classes)

# Get predicted class labels
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# Accuracy and report
print("Accuracy:", accuracy_score(y_val, y_pred_labels))
print(classification_report(y_val, y_pred_labels))
#f1_score 
print("Weighted F1 Score:", f1_score(y_val,y_pred_labels,average='weighted'))
# Out:
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.2776 - loss: 2.1749
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - accuracy: 0.5732 - loss: 1.5373
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.6606 - loss: 1.2770
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.7240 - loss: 1.1091
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.7680 - loss: 0.9944
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.8074 - loss: 0.9004
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.8426 - loss: 0.8218
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.8622 - loss: 0.7557
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.8875 - loss: 0.6950
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.9068 - loss: 0.6451
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 0.9313 - loss: 0.6002
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.9405 - loss: 0.5667
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9543 - loss: 0.5309
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.9586 - loss: 0.5071
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.9693 - loss: 0.4821
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - accuracy: 0.9657 - loss: 0.4661
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 0.9592 - loss: 0.4793
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.9254 - loss: 0.5995
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.9273 - loss: 0.5410
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9667 - loss: 0.4649
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.9696 - loss: 0.4353
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.9830 - loss: 0.4203
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.9830 - loss: 0.3953
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.9887 - loss: 0.3794
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.9849 - loss: 0.3796
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.9908 - loss: 0.3677
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.9913 - loss: 0.3584
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.9896 - loss: 0.3593
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9906 - loss: 0.3496
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.9860 - loss: 0.3504
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.9859 - loss: 0.3457
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.9952 - loss: 0.3252
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.9959 - loss: 0.3193
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 0.9982 - loss: 0.3087
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.9975 - loss: 0.2972
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.9997 - loss: 0.2874
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.9984 - loss: 0.2820
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - accuracy: 0.9971 - loss: 0.2787
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.9986 - loss: 0.2715
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.9974 - loss: 0.2652
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.9986 - loss: 0.2607
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.9997 - loss: 0.2532
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.9983 - loss: 0.2467
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.9986 - loss: 0.2430
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 1.0000 - loss: 0.2354
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 1.0000 - loss: 0.2312
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.9986 - loss: 0.2280
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 1.0000 - loss: 0.2212
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 1.0000 - loss: 0.2173
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - accuracy: 1.0000 - loss: 0.2127
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.7942973523421588
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        75
#            1       0.87      0.87      0.87        75
#            2       0.57      0.62      0.59        39
#            3       0.87      0.77      0.82        75
#            4       0.89      0.77      0.83        75
#            5       0.73      0.79      0.76        38
#            6       0.80      0.80      0.80        75
#            7       0.63      0.82      0.71        39
#
#     accuracy                           0.79       491
#    macro avg       0.77      0.78      0.78       491
# weighted avg       0.80      0.79      0.80       491
#
# Weighted F1 Score: 0.7965695859771391
